# %%
# Set up the environment

import sys

# Add path for python to look into for modules installed using pip

sys.path.append('/usr/local/lib/python3.7/site-packages/')

import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/all_data.csv', sep=',', index_col=0)

# %%
data.head()
# Out:
#             adjusted_close     volume  dividend_amount  split_coefficient  \
# 2020-02-21         2095.97  4650740.0              0.0                1.0
# 2020-02-20         2153.10  3131342.0              0.0                1.0
# 2020-02-19         2170.22  2561165.0              0.0                1.0
# 2020-02-18         2155.67  2951070.0              0.0                1.0
# 2020-02-14         2134.87  2606169.0              0.0                1.0
#
#             daily_range  relative_returns  log_returns       ema_20  \
# 2020-02-21        56.55          0.043140     0.042235  1928.512028
# 2020-02-20        49.34          0.027257     0.026892  1949.901359
# 2020-02-19        23.98          0.007951     0.007920  1970.884087
# 2020-02-18        41.96         -0.006704    -0.006727  1988.482745
# 2020-02-14        33.15         -0.009649    -0.009696  2002.424388
#
#                  ema_50      ema_100  ...  DEXUSAL  DEXSZUS  DEXTHUS  DEXTAUS  \
# 2020-02-21  1903.375642  1893.879522  ...   0.6632   0.9781    31.55    30.40
# 2020-02-20  1913.168754  1899.012600  ...   0.6618   0.9831    31.43    30.26
# 2020-02-19  1923.249195  1904.383044  ...   0.6673   0.9839    31.21    30.11
# 2020-02-18  1932.363737  1909.359023  ...   0.6693   0.9814    31.16    30.11
# 2020-02-14  1940.305159  1913.824587  ...   0.6719   0.9818    31.21    30.02
#
#             DEXSFUS  DEXHKUS  DEXMAUS  DEXSDUS  DEXSIUS  DEXNOUS
# 2020-02-21   14.966   7.7873   4.1890   9.7269   1.3970   9.2782
# 2020-02-20   15.118   7.7831   4.1806   9.8168   1.4005   9.3194
# 2020-02-19   14.980   7.7719   4.1599   9.8041   1.3945   9.2762
# 2020-02-18   14.975   7.7674   4.1540   9.7715   1.3921   9.3092
# 2020-02-14   14.900   7.7672   4.1400   9.7176   1.3921   9.2479
#
# [5 rows x 53 columns]
